# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
dframe1 = DataFrame({'key':['X','X','X','S','Z','A'], 'data_set_1': np.arange(6)})
dframe1
# Out:
#   key  data_set_1
# 0   X           0
# 1   X           1
# 2   X           2
# 3   S           3
# 4   Z           4
# 5   A           5

# %%
dframe2 = DataFrame({'key':['Q','X','A'], 'data_set_2':[1,2,3]})
dframe2
# Out:
#   key  data_set_2
# 0   Q           1
# 1   X           2
# 2   A           3

# %%
pd.merge(dframe1,dframe2)
# Out:
#   key  data_set_1  data_set_2
# 0   X           0           2
# 1   X           1           2
# 2   X           2           2
# 3   A           5           3

# %%
pd.merge(dframe1, dframe2, on='key')
# Out:
#   key  data_set_1  data_set_2
# 0   X           0           2
# 1   X           1           2
# 2   X           2           2
# 3   A           5           3

# %%
pd.merge(dframe1, dframe2, on='key',how='left')
# Out:
#   key  data_set_1  data_set_2
# 0   X           0         2.0
# 1   X           1         2.0
# 2   X           2         2.0
# 3   S           3         NaN
# 4   Z           4         NaN
# 5   A           5         3.0

# %%
dframe2
# Out:
#   key  data_set_2
# 0   Q           1
# 1   X           2
# 2   A           3

# %%
pd.merge(dframe1, dframe2, on='key',how='right')
# Out:
#   key  data_set_1  data_set_2
# 0   X         0.0           2
# 1   X         1.0           2
# 2   X         2.0           2
# 3   A         5.0           3
# 4   Q         NaN           1

# %%
pd.merge(dframe1, dframe2, on='key',how='outer')
# Out:
#   key  data_set_1  data_set_2
# 0   X         0.0         2.0
# 1   X         1.0         2.0
# 2   X         2.0         2.0
# 3   S         3.0         NaN
# 4   Z         4.0         NaN
# 5   A         5.0         3.0
# 6   Q         NaN         1.0

# %%
dframe3 = DataFrame({'key':['X','X','X','Y','Z','Z'], 'data_set_3': range(6)})

# %%
dframe4 = DataFrame({'key':['X','Y','X','Y','Z'], 'data_set_4': range(5)})

# %%
dframe3
# Out:
#   key  data_set_3
# 0   X           0
# 1   X           1
# 2   X           2
# 3   Y           3
# 4   Z           4
# 5   Z           5

# %%
dframe4
# Out:
#   key  data_set_4
# 0   X           0
# 1   Y           1
# 2   X           2
# 3   Y           3
# 4   Z           4

# %%
pd.merge(dframe3, dframe4)
# Out:
#   key  data_set_3
# 0   X           0
# 1   X           2
# 2   Y           3
# 3   Z           4

# %%
df_left = DataFrame({'key1':['','','','','','']})
